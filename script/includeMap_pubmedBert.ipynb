# %%
import pandas as pd
import numpy as np
import concurrent.futures
import matplotlib.pyplot as plt
import seaborn as sns

# %%
icd9 = pd.read_json('../data/icd9-cm-2015-code.json').T
icd9 = icd9.reset_index(names="Code")
icd9
# Out:
# /tmp/ipykernel_1316760/641046097.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   icd9 = pd.read_json('../data/icd9-cm-2015-code.json').T
# /tmp/ipykernel_1316760/641046097.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   icd9 = pd.read_json('../data/icd9-cm-2015-code.json').T
# /tmp/ipykernel_1316760/641046097.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   icd9 = pd.read_json('../data/icd9-cm-2015-code.json').T
#       Code   code                                              title  \
# 0       00     00  Procedures and interventions , Not Elsewhere C...
# 1      000   00.0                             Therapeutic ultrasound
# 2     0001  00.01  Therapeutic ultrasound of vessels of head and ...
# 3     0002  00.02                    Therapeutic ultrasound of heart
# 4     0003  00.03  Therapeutic ultrasound of peripheral vascular ...
# ...    ...    ...                                                ...
# 4641  9995  99.95                             Stretching of foreskin
# 4642  9996  99.96    Collection of sperm for artificial insemination
# 4643  9997  99.97                                 Fitting of denture
# 4644  9998  99.98           Extraction of milk from lactating breast
# 4645  9999  99.99                                              Other
#
#                                                 exclude  sex  \
# 0                                                   NaN  NaN
# 1     [diagnostic ultrasound (non-invasive) (88.71-8...  NaN
# 2     [diagnostic ultrasound of: eye (95.13), diagno...    B
# 3     [diagnostic ultrasound of heart (88.72), ultra...    B
# 4     [diagnostic ultrasound of peripheral vascular ...    B
# ...                                                 ...  ...
# 4641                                                NaN    B
# 4642                                                NaN    M
# 4643                                                NaN    B
# 4644                                                NaN    F
# 4645                                                NaN    B
#
#                                                 synonym include codeAlso note  \
# 0                                                   NaN     NaN      NaN  NaN
# 1                                                   NaN     NaN      NaN  NaN
# 2     [Anti-restenotic ultrasound, Intravascular non...     NaN      NaN  NaN
# 3     [Anti-restenotic ultrasound, Intravascular non...     NaN      NaN  NaN
# 4     [Anti-restenotic ultrasound, Intravascular non...     NaN      NaN  NaN
# ...                                                 ...     ...      ...  ...
# 4641                                                NaN     NaN      NaN  NaN
# 4642                                                NaN     NaN      NaN  NaN
# 4643                                                NaN     NaN      NaN  NaN
# 4644                                                NaN     NaN      NaN  NaN
# 4645                                    [Leech therapy]     NaN      NaN  NaN
#
#      fourth-digit
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4641          NaN
# 4642          NaN
# 4643          NaN
# 4644          NaN
# 4645          NaN
#
# [4646 rows x 10 columns]

# %% [markdown]
# ### if code is already exist in other code inclusion then remove

# %%
# Map from inclusion to icd9 for defining including icd9
# Prepare all name of icd9 from title, synonym, and exclude
title = icd9[["Code", "title"]].copy()

# %%
syn = icd9[["Code", "synonym"]].copy().explode("synonym").dropna()
syn = syn.rename(columns={"synonym": "title"})
syn
# Out:
#       Code                                              title
# 2     0001                         Anti-restenotic ultrasound
# 2     0001              Intravascular non-ablative ultrasound
# 3     0002                         Anti-restenotic ultrasound
# 3     0002              Intravascular non-ablative ultrasound
# 4     0003                         Anti-restenotic ultrasound
# ...    ...                                                ...
# 4633  9985  Hyperthermia (adjunct therapy) induced by micr...
# 4634  9986  Transcutaneous (surface) placement of pads or ...
# 4635  9988                   Extracorporeal photochemotherapy
# 4635  9988                       Extracorporeal photopheresis
# 4645  9999                                      Leech therapy
#
# [4272 rows x 2 columns]

# %%
exc = icd9[["exclude"]].dropna().explode("exclude").drop_duplicates()
exc[["title", "Code"]] = exc["exclude"].str.extract(r'^(.*)\(([^)]+)\)[^()]*$')
exc["title"] = exc["title"].str.strip()
exc["Code"] = exc["Code"].str.replace('.','')
exc = exc.drop(columns=['exclude'])
exc
# Out:
#                                                   title  \
# 1                  diagnostic ultrasound (non-invasive)
# 1     intracardiac echocardiography [ICE] (heart cha...
# 1                    intravascular imaging (adjunctive)
# 2                         diagnostic ultrasound of: eye
# 2               diagnostic ultrasound of: head and neck
# ...                                                 ...
# 4631                 photocoagulation of retinal lesion
# 4634  insertion of invasive or semi invasive bone gr...
# 4635                                 other phototherapy
# 4635                           ultraviolet light therap
# 4638        Other acupuncture that with smouldering mox
#
#                                  Code
# 1                           8871-8879
# 1                                3728
# 1                           0021-0029
# 2                                9513
# 2                                8871
# ...                               ...
# 4631  1423-1425, 1433-1435, 1453-1455
# 4634                        7890-7899
# 4635                             9983
# 4635                             9982
# 4638                             9335
#
# [2055 rows x 2 columns]

# %%
codeAlso = icd9[["codeAlso"]].dropna().explode("codeAlso").drop_duplicates()
codeAlso[["title", "Code"]] = codeAlso["codeAlso"].str.extract(r'^(.*)\(([^)]+)\)[^()]*$')
codeAlso["title"] = codeAlso["title"].str.strip()
codeAlso["Code"] = codeAlso["Code"].str.replace('.','')
codeAlso = codeAlso.dropna()
codeAlso = codeAlso.drop(columns=['codeAlso'])
codeAlso

# %%
main = pd.concat([title, syn, exc, codeAlso], ignore_index=True)
main = main.drop_duplicates()
main
# Out:
#                                   Code  \
# 0                                   00
# 1                                  000
# 2                                 0001
# 3                                 0002
# 4                                 0003
# ...                                ...
# 10968  1423-1425, 1433-1435, 1453-1455
# 10969                        7890-7899
# 10970                             9983
# 10971                             9982
# 10972                             9335
#
#                                                    title
# 0      Procedures and interventions , Not Elsewhere C...
# 1                                 Therapeutic ultrasound
# 2      Therapeutic ultrasound of vessels of head and ...
# 3                        Therapeutic ultrasound of heart
# 4      Therapeutic ultrasound of peripheral vascular ...
# ...                                                  ...
# 10968                 photocoagulation of retinal lesion
# 10969  insertion of invasive or semi invasive bone gr...
# 10970                                 other phototherapy
# 10971                           ultraviolet light therap
# 10972        Other acupuncture that with smouldering mox
#
# [10923 rows x 2 columns]

# %%
inc = icd9[["include"]].dropna().explode("include").copy()
inc
# Out:
#                                                 include
# 15    during induction phase of solid organ transpla...
# 15                          monoclonal antibody therapy
# 15                          polyclonal antibody therapy
# 53                        fractional flow reserve (FFR)
# 58    the use of any embolic protection device, dist...
# ...                                                 ...
# 4560  injection or infusion given: intramuscularly a...
# 4560  injection or infusion given: intravenously act...
# 4571  injection or infusion given: hypodermically ac...
# 4571  injection or infusion given: intramuscularly a...
# 4571  injection or infusion given: intravenously act...
#
# [277 rows x 1 columns]

# %%
from sentence_transformers import SentenceTransformer, util

# 1. Load the model 
print("Loading Transformer model...")
model = SentenceTransformer('microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext') # This model was previously named "PubMedBERT (abstracts + full text)".

# 2. Prepare the arrays
choices = main["title"].dropna().unique()
queries = inc['include'].dropna().unique()

# 3. Convert text to embeddings (Vectors)
# show_progress_bar=True will give you a nice visual of the encoding speed
print(f"Encoding {len(choices)} target choices into vectors...")
corpus_embeddings = model.encode(choices, convert_to_tensor=True, show_progress_bar=True)

print(f"Encoding {len(queries)} query inclusions into vectors...")
query_embeddings = model.encode(queries, convert_to_tensor=True, show_progress_bar=True)

# 4. Calculate Cosine Similarity
print("Calculating top 5 matches via Cosine Similarity...")
hits = util.semantic_search(query_embeddings, corpus_embeddings, top_k=5)

results = []
for query_idx, hit_list in enumerate(hits):
    query_text = queries[query_idx]
    for rank, hit in enumerate(hit_list, start=1):
        matched_title = choices[hit['corpus_id']]
        score = min(100, hit['score'] * 100)
        
        results.append({
            "include": query_text,
            "rank": rank,
            "matched_title": matched_title,
            "score": score
        })

top5_df = pd.DataFrame(results)
top5_df
# Out:
# Loading Transformer model...
# /home/admin/anaconda3/lib/python3.12/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Encoding 10527 target choices into vectors...
# Batches:   0%|          | 0/329 [00:00<?, ?it/s]
# Encoding 238 query inclusions into vectors...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating top 5 matches via Cosine Similarity...
#                                                 include  rank  \
# 0     during induction phase of solid organ transpla...     1
# 1     during induction phase of solid organ transpla...     2
# 2     during induction phase of solid organ transpla...     3
# 3     during induction phase of solid organ transpla...     4
# 4     during induction phase of solid organ transpla...     5
# ...                                                 ...   ...
# 1185  injection or infusion given: intravenously act...     1
# 1186  injection or infusion given: intravenously act...     2
# 1187  injection or infusion given: intravenously act...     3
# 1188  injection or infusion given: intravenously act...     4
# 1189  injection or infusion given: intravenously act...     5
#
#                                           matched_title      score
# 0        Allogeneic bone marrow transplant with purging  97.026956
# 1     Allograft of bone marrow with in vitro removal...  96.999949
# 2     Extracorporeal circulation auxiliary to open h...  96.897912
# 3     extracorporeal circulation auxiliary to open h...  96.897912
# 4     Extracorporeal circulation and procedures auxi...  96.893322
# ...                                                 ...        ...
# 1185  Injection or infusion of therapeutic or prophy...  97.921538
# 1186  injection or infusion of therapeutic or prophy...  97.921538
# 1187  Injection or infusion of other therapeutic or ...  97.799540
# 1188  Other puncture of vein that for: injection or ...  97.777987
# 1189  Injection of locally-acting therapeutic substa...  97.697312
#
# [1190 rows x 4 columns]

# %%
# Margin Thresholding
rank1 = top5_df[top5_df['rank'] == 1].set_index('include')[['matched_title', 'score']]
rank2 = top5_df[top5_df['rank'] == 2].set_index('include')[['score']]
rank1 = rank1.rename(columns={'score': 'rank1_score'})
rank2 = rank2.rename(columns={'score': 'rank2_score'})

# 3. Join them together and calculate the Delta (Margin)
confidence_df = rank1.join(rank2)
confidence_df['margin'] = confidence_df['rank1_score'] - confidence_df['rank2_score'].fillna(0)

# 4. Define your two-part cutoff rules:
# Rule A: The absolute score must be decently high (e.g., > 75)
# Rule B: The gap between 1st and 2nd place must be clear (e.g., > 10 points)
safe_matches = confidence_df.query('rank1_score >= 75 and margin >= 1')
review_matches = confidence_df.query('rank1_score < 75 or margin < 1')

print(f"Successfully Mapped: {len(safe_matches) / len(queries):.2%} ({len(safe_matches)} out of {len(queries)} inclusions)")

safe_matches = safe_matches.reset_index(names='include').merge(main, left_on='matched_title', right_on='title', how='left')
safe_matches = safe_matches.drop(columns = ["title"])
safe_matches
# Out:
# Successfully Mapped: 4.62% (11 out of 238 inclusions)
#                                               include  \
# 0                         monoclonal antibody therapy
# 1                         polyclonal antibody therapy
# 2            Intra-operative neurophysiologic testing
# 3                         operations on: pineal gland
# 4                           Excimer laser atherectomy
# 5                           Excimer laser atherectomy
# 6                           Excimer laser atherectomy
# 7   reduction with insertion of traction device (K...
# 8   removal of posterior spinal motion preservatio...
# 9   microsurgical suture repair with fascial autog...
# 10              correction of pseudarthrosis of spine
# 11                         operations on: aponeurosis
# 12                                    Ultrasonography
# 13                                    Ultrasonography
#
#                                         matched_title  rank1_score  \
# 0      Infusion of immunosuppressive antibody therapy    98.474348
# 1      Infusion of immunosuppressive antibody therapy    98.020071
# 2         Intra-operative neurophysiologic monitoring    99.491405
# 3                         operations on: pineal gland    99.999982
# 4                           Excimer laser atherectomy    99.999970
# 5                           Excimer laser atherectomy    99.999970
# 6                           Excimer laser atherectomy    99.999970
# 7   removal of cast, splint, and traction device (...    99.260849
# 8   removal of posterior spinal motion preservatio...    99.898708
# 9   Microsurgical suture repair without fascial au...    99.729502
# 10              correction of pseudarthrosis of spine   100.000000
# 11                           Excision of: aponeurosis    98.638910
# 12                                    ultrasonography   100.000000
# 13                                    ultrasonography   100.000000
#
#     rank2_score    margin             Code
# 0     96.812761  1.661587             0018
# 1     96.966249  1.053822             0018
# 2     98.244965  1.246440             0094
# 3     98.756105  1.243877  0717, 0751-0759
# 4     97.993684  2.006286             1753
# 5     97.993684  2.006286             1754
# 6     97.993684  2.006286             1755
# 7     98.056132  1.204717             9788
# 8     98.875111  1.023597             8009
# 9     97.601253  2.128249             8054
# 10    98.103482  1.896518       8130- 8139
# 11    97.561032  1.077878             8342
# 12    97.058350  2.941650             8874
# 13    97.058350  2.941650             8873

# %%
rank1_df = top5_df.query('rank == 1')
P = 95 # Increase for higher confidence, and vice versa.
threshold = np.percentile(rank1_df['score'], P)

fig, ax = plt.subplots(figsize=(12, 4))
sns.histplot(
    data=rank1_df, 
    x="score", 
    bins=30,
    ax=ax
)

ax.axvline(x=threshold, color='red', linestyle='--', linewidth=2, label=f'{P}th Percentile Threshold ({threshold:.3f})')

ax.set_title("Distribution of Scores (Rank 1)", fontsize=12)
ax.set_xlabel("PubmedBERT Cosine Similarity", fontsize=12)
ax.set_ylabel("Number of Inclusion Texts", fontsize=12)
ax.legend()

plt.tight_layout()
plt.show()

# %%
cutoff_res = top5_df.query(f'score >= {threshold}')

mapped_count = len(cutoff_res['include'].unique())
total_count = len(queries)
print(f"Successfully Mapped: {mapped_count / total_count:.2%} ({mapped_count} out of {total_count} inclusions)")

cutoff_res = cutoff_res.merge(main, left_on='matched_title', right_on='title', how='left')
cutoff_res = cutoff_res.drop(columns = ["title"])
cutoff_res
# Out:
# Successfully Mapped: 5.04% (12 out of 238 inclusions)
#                                               include  rank  \
# 0                         operations on: pineal gland     1
# 1                             Directional atherectomy     1
# 2                             Directional atherectomy     1
# 3                             Directional atherectomy     1
# 4                           Excimer laser atherectomy     1
# 5                           Excimer laser atherectomy     1
# 6                           Excimer laser atherectomy     1
# 7                              Rotational atherectomy     1
# 8                              Rotational atherectomy     1
# 9                              Rotational atherectomy     1
# 10                                      mastoidectomy     1
# 11                                operations on: lips     1
# 12                                operations on: lips     1
# 13                                operations on: lips     2
# 14                                  electrocardiogram     1
# 15                                  electrocardiogram     2
# 16                               Complete proctectomy     1
# 17  removal of posterior spinal motion preservatio...     1
# 18  microsurgical suture repair with fascial autog...     1
# 19              correction of pseudarthrosis of spine     1
# 20                                    Ultrasonography     1
# 21                                    Ultrasonography     1
#
#                                         matched_title       score  \
# 0                         operations on: pineal gland   99.999982
# 1                             Directional atherectomy  100.000000
# 2                             Directional atherectomy  100.000000
# 3                             Directional atherectomy  100.000000
# 4                           Excimer laser atherectomy   99.999970
# 5                           Excimer laser atherectomy   99.999970
# 6                           Excimer laser atherectomy   99.999970
# 7                              Rotational atherectomy  100.000000
# 8                              Rotational atherectomy  100.000000
# 9                              Rotational atherectomy  100.000000
# 10                                      Mastoidectomy   99.999994
# 11                               operations on: skull   99.640465
# 12                               operations on: skull   99.640465
# 13                           operations on: vertebrae   99.631661
# 14                                  Electrocardiogram  100.000000
# 15                                  electrocardiogram  100.000000
# 16                                Partial proctectomy   99.669510
# 17  removal of posterior spinal motion preservatio...   99.898708
# 18  Microsurgical suture repair without fascial au...   99.729502
# 19              correction of pseudarthrosis of spine  100.000000
# 20                                    ultrasonography  100.000000
# 21                                    ultrasonography  100.000000
#
#                Code
# 0   0717, 0751-0759
# 1              1753
# 2              1754
# 3              1755
# 4              1753
# 5              1754
# 6              1755
# 7              1753
# 8              1754
# 9              1755
# 10              204
# 11        0101-0299
# 12             0202
# 13             0353
# 14             8952
# 15             8952
# 16             4869
# 17             8009
# 18             8054
# 19       8130- 8139
# 20             8874
# 21             8873

# %%
# Margin map + P95 threshold map
inc_map_all = pd.concat([cutoff_res, safe_matches])
inc_map = inc_map_all[["Code", "include"]].drop_duplicates()
print(f"Successfully Mapped: {len(inc_map['include'].unique()) / len(queries):.2%} ({len(inc_map['include'].unique())} out of {len(queries)} inclusions)")
inc_map
# Out:
# Successfully Mapped: 7.14% (17 out of 238 inclusions)
#                Code                                            include
# 0   0717, 0751-0759                        operations on: pineal gland
# 1              1753                            Directional atherectomy
# 2              1754                            Directional atherectomy
# 3              1755                            Directional atherectomy
# 4              1753                          Excimer laser atherectomy
# 5              1754                          Excimer laser atherectomy
# 6              1755                          Excimer laser atherectomy
# 7              1753                             Rotational atherectomy
# 8              1754                             Rotational atherectomy
# 9              1755                             Rotational atherectomy
# 10              204                                      mastoidectomy
# 11        0101-0299                                operations on: lips
# 12             0202                                operations on: lips
# 13             0353                                operations on: lips
# 14             8952                                  electrocardiogram
# 16             4869                               Complete proctectomy
# 17             8009  removal of posterior spinal motion preservatio...
# 18             8054  microsurgical suture repair with fascial autog...
# 19       8130- 8139              correction of pseudarthrosis of spine
# 20             8874                                    Ultrasonography
# 21             8873                                    Ultrasonography
# 0              0018                        monoclonal antibody therapy
# 1              0018                        polyclonal antibody therapy
# 2              0094           Intra-operative neurophysiologic testing
# 7              9788  reduction with insertion of traction device (K...
# 11             8342                         operations on: aponeurosis

# %%
icd9_inc = icd9[["Code", "title", "include"]].dropna()
icd9_inc = icd9_inc.explode("include")
icd9_inc = icd9_inc.merge(inc_map, on='include', how='inner', suffixes=('','_include'))

# Exclude map include to self
icd9_inc = icd9_inc.query("Code != Code_include")
icd9_inc = icd9_inc.groupby(by=['Code', 'title', 'include'],as_index=False).agg(list)
icd9_inc
# Out:
#     Code                                              title  \
# 0     07               Operations on other endocrine glands
# 1   1756        Atherectomy of other non-coronary vessel(s)
# 2   1756        Atherectomy of other non-coronary vessel(s)
# 3   1756        Atherectomy of other non-coronary vessel(s)
# 4   2096  Implantation or replacement of cochlear prosth...
# 5   2097  Implantation or replacement of cochlear prosth...
# 6   2098  Implantation or replacement of cochlear prosth...
# 7     27                 Other operations on mouth and face
# 8   3897    Central venous catheter placement with guidance
# 9    485               Abdominoperineal resection of rectum
# 10    79              Reduction of fracture and dislocation
# 11   800  Arthrotomy for removal of prosthesis without r...
# 12  8000  Arthrotomy for removal of prosthesis without r...
# 13  8001  Arthrotomy for removal of prosthesis without r...
# 14  8002  Arthrotomy for removal of prosthesis without r...
# 15  8003  Arthrotomy for removal of prosthesis without r...
# 16  8004  Arthrotomy for removal of prosthesis without r...
# 17  8005  Arthrotomy for removal of prosthesis without r...
# 18  8006  Arthrotomy for removal of prosthesis without r...
# 19  8007  Arthrotomy for removal of prosthesis without r...
# 20  8008  Arthrotomy for removal of prosthesis without r...
# 21  8053  Repair of the anulus fibrosus with graft or pr...
# 22   813                                  Refusion of spine
# 23    82   Operations on muscle, tendon, and fascia of hand
# 24    83  Operations on muscle, tendon, fascia, and burs...
# 25   887                              Diagnostic ultrasound
#
#                                               include             Code_include
# 0                         operations on: pineal gland        [0717, 0751-0759]
# 1                             Directional atherectomy       [1753, 1754, 1755]
# 2                           Excimer laser atherectomy       [1753, 1754, 1755]
# 3                              Rotational atherectomy       [1753, 1754, 1755]
# 4                                       mastoidectomy                    [204]
# 5                                       mastoidectomy                    [204]
# 6                                       mastoidectomy                    [204]
# 7                                 operations on: lips  [0101-0299, 0202, 0353]
# 8                                   electrocardiogram                   [8952]
# 9                                Complete proctectomy                   [4869]
# 10  reduction with insertion of traction device (K...                   [9788]
# 11  removal of posterior spinal motion preservatio...                   [8009]
# 12  removal of posterior spinal motion preservatio...                   [8009]
# 13  removal of posterior spinal motion preservatio...                   [8009]
# 14  removal of posterior spinal motion preservatio...                   [8009]
# 15  removal of posterior spinal motion preservatio...                   [8009]
# 16  removal of posterior spinal motion preservatio...                   [8009]
# 17  removal of posterior spinal motion preservatio...                   [8009]
# 18  removal of posterior spinal motion preservatio...                   [8009]
# 19  removal of posterior spinal motion preservatio...                   [8009]
# 20  removal of posterior spinal motion preservatio...                   [8009]
# 21  microsurgical suture repair with fascial autog...                   [8054]
# 22              correction of pseudarthrosis of spine             [8130- 8139]
# 23                         operations on: aponeurosis                   [8342]
# 24                         operations on: aponeurosis                   [8342]
# 25                                    Ultrasonography             [8874, 8873]

# %%
def expand_icd9(interval_string : str, valid_codes : list[str]):
    """
    Expands ICD-9 strings into individual codes, 
    filtering against a list of known valid codes.
    """
    valid_set = set(valid_codes)
    expanded_codes = []

    parts = [p.strip() for p in interval_string.split(',')]

    for part in parts:
        if '-' in part:
            # Step 1: Split the range (e.g., "0751-0759")
            start, end = part.split('-')
            start = start.strip()
            end = end.strip()
            

            # Step 3: Track the length to maintain leading zeros (e.g., 4 characters)
            num_length = len(start)

            # Step 4: Generate the sequence
            for num in range(int(start), int(end) + 1):
                generated_code = str(num).zfill(num_length)
                
                # Step 5: Only add it if it actually exists in your data
                if generated_code in valid_set:
                    expanded_codes.append(generated_code)

        else:
            base_code = part.strip()
            
            # Loop through the valid set to find the exact code AND any detailed sub-codes
            for valid_code in valid_set:
                if valid_code.startswith(base_code):
                    expanded_codes.append(valid_code)

    return sorted(expanded_codes)

print(expand_icd9('0717, 0751-0759', icd9['Code'].tolist()))
print(expand_icd9('8130- 8139', icd9['Code'].tolist()))
print(expand_icd9('204', icd9['Code'].tolist()))
# Out:
# ['0717', '0751', '0752', '0753', '0754', '0759']
# ['8130', '8131', '8132', '8133', '8134', '8135', '8136', '8137', '8138', '8139']
# ['204', '2041', '2042', '2049']

# %%
valid_set = icd9['Code'].tolist()
icd9_inc['Code_include_expand'] = icd9_inc['Code_include'].apply(
    lambda x: sorted(list(set(
        expanded_code 
        for c in x 
        for expanded_code in expand_icd9(c, valid_set)
    ))) if isinstance(x, list) else []
)
icd9_inc
# Out:
#     Code                                              title  \
# 0     07               Operations on other endocrine glands
# 1   1756        Atherectomy of other non-coronary vessel(s)
# 2   1756        Atherectomy of other non-coronary vessel(s)
# 3   1756        Atherectomy of other non-coronary vessel(s)
# 4   2096  Implantation or replacement of cochlear prosth...
# 5   2097  Implantation or replacement of cochlear prosth...
# 6   2098  Implantation or replacement of cochlear prosth...
# 7     27                 Other operations on mouth and face
# 8   3897    Central venous catheter placement with guidance
# 9    485               Abdominoperineal resection of rectum
# 10    79              Reduction of fracture and dislocation
# 11   800  Arthrotomy for removal of prosthesis without r...
# 12  8000  Arthrotomy for removal of prosthesis without r...
# 13  8001  Arthrotomy for removal of prosthesis without r...
# 14  8002  Arthrotomy for removal of prosthesis without r...
# 15  8003  Arthrotomy for removal of prosthesis without r...
# 16  8004  Arthrotomy for removal of prosthesis without r...
# 17  8005  Arthrotomy for removal of prosthesis without r...
# 18  8006  Arthrotomy for removal of prosthesis without r...
# 19  8007  Arthrotomy for removal of prosthesis without r...
# 20  8008  Arthrotomy for removal of prosthesis without r...
# 21  8053  Repair of the anulus fibrosus with graft or pr...
# 22   813                                  Refusion of spine
# 23    82   Operations on muscle, tendon, and fascia of hand
# 24    83  Operations on muscle, tendon, fascia, and burs...
# 25   887                              Diagnostic ultrasound
#
#                                               include  \
# 0                         operations on: pineal gland
# 1                             Directional atherectomy
# 2                           Excimer laser atherectomy
# 3                              Rotational atherectomy
# 4                                       mastoidectomy
# 5                                       mastoidectomy
# 6                                       mastoidectomy
# 7                                 operations on: lips
# 8                                   electrocardiogram
# 9                                Complete proctectomy
# 10  reduction with insertion of traction device (K...
# 11  removal of posterior spinal motion preservatio...
# 12  removal of posterior spinal motion preservatio...
# 13  removal of posterior spinal motion preservatio...
# 14  removal of posterior spinal motion preservatio...
# 15  removal of posterior spinal motion preservatio...
# 16  removal of posterior spinal motion preservatio...
# 17  removal of posterior spinal motion preservatio...
# 18  removal of posterior spinal motion preservatio...
# 19  removal of posterior spinal motion preservatio...
# 20  removal of posterior spinal motion preservatio...
# 21  microsurgical suture repair with fascial autog...
# 22              correction of pseudarthrosis of spine
# 23                         operations on: aponeurosis
# 24                         operations on: aponeurosis
# 25                                    Ultrasonography
#
#                Code_include                                Code_include_expand
# 0         [0717, 0751-0759]               [0717, 0751, 0752, 0753, 0754, 0759]
# 1        [1753, 1754, 1755]                                 [1753, 1754, 1755]
# 2        [1753, 1754, 1755]                                 [1753, 1754, 1755]
# 3        [1753, 1754, 1755]                                 [1753, 1754, 1755]
# 4                     [204]                            [204, 2041, 2042, 2049]
# 5                     [204]                            [204, 2041, 2042, 2049]
# 6                     [204]                            [204, 2041, 2042, 2049]
# 7   [0101-0299, 0202, 0353]  [0101, 0102, 0109, 0110, 0111, 0112, 0113, 011...
# 8                    [8952]                                             [8952]
# 9                    [4869]                                             [4869]
# 10                   [9788]                                             [9788]
# 11                   [8009]                                             [8009]
# 12                   [8009]                                             [8009]
# 13                   [8009]                                             [8009]
# 14                   [8009]                                             [8009]
# 15                   [8009]                                             [8009]
# 16                   [8009]                                             [8009]
# 17                   [8009]                                             [8009]
# 18                   [8009]                                             [8009]
# 19                   [8009]                                             [8009]
# 20                   [8009]                                             [8009]
# 21                   [8054]                                             [8054]
# 22             [8130- 8139]  [8130, 8131, 8132, 8133, 8134, 8135, 8136, 813...
# 23                   [8342]                                             [8342]
# 24                   [8342]                                             [8342]
# 25             [8874, 8873]                                       [8873, 8874]

# %%
# Export summary table
# 1. Prepare Sheet 1 Data
icd9_inc_export = icd9_inc.copy()
list_val_cols = ["Code_include", "Code_include_expand"]

for c in list_val_cols:
    icd9_inc_export[c] = icd9_inc_export[c].apply(
        lambda x: ', '.join([str(i) for i in x]) if isinstance(x, list) else x
    )
display(icd9_inc_export)
    
# 2. Prepare Sheet 2 All mapping score
top5_df_res = top5_df.merge(
    main, left_on='matched_title', right_on='title', how='left'
).drop(columns=['title'])
top5_df_res = top5_df_res.groupby(by = top5_df_res.columns[:-1].tolist(), as_index=False).agg(list)
ground_truth = (
    inc_map_all[['include', 'matched_title']]
    .drop_duplicates())

top5_df_res = top5_df_res.merge(ground_truth, on=['include', 'matched_title'], how='left', indicator=True)
top5_df_res['IS_MAP'] = top5_df_res['_merge'] == "both"
top5_df_res = top5_df_res.drop(columns = '_merge')
top5_df_res['Code'] = top5_df_res['Code'].apply(
        lambda x: ', '.join([str(i) for i in x]) if isinstance(x, list) else x
    )
display(top5_df_res)


# 2. Export to Excel
output_filename = "../result/icd9_inclusion_mapping_summary.xlsx"
print(f"Exporting data to {output_filename}...")

with pd.ExcelWriter(output_filename, engine='xlsxwriter') as writer:
    icd9_inc_export.to_excel(writer, sheet_name='Inclusion Mapping', index=False)
    top5_df_res.to_excel(writer, sheet_name='Top 5 Matches', index=False)
# Out:
#     Code                                              title  \
# 0     07               Operations on other endocrine glands
# 1   1756        Atherectomy of other non-coronary vessel(s)
# 2   1756        Atherectomy of other non-coronary vessel(s)
# 3   1756        Atherectomy of other non-coronary vessel(s)
# 4   2096  Implantation or replacement of cochlear prosth...
# 5   2097  Implantation or replacement of cochlear prosth...
# 6   2098  Implantation or replacement of cochlear prosth...
# 7     27                 Other operations on mouth and face
# 8   3897    Central venous catheter placement with guidance
# 9    485               Abdominoperineal resection of rectum
# 10    79              Reduction of fracture and dislocation
# 11   800  Arthrotomy for removal of prosthesis without r...
# 12  8000  Arthrotomy for removal of prosthesis without r...
# 13  8001  Arthrotomy for removal of prosthesis without r...
# 14  8002  Arthrotomy for removal of prosthesis without r...
# 15  8003  Arthrotomy for removal of prosthesis without r...
# 16  8004  Arthrotomy for removal of prosthesis without r...
# 17  8005  Arthrotomy for removal of prosthesis without r...
# 18  8006  Arthrotomy for removal of prosthesis without r...
# 19  8007  Arthrotomy for removal of prosthesis without r...
# 20  8008  Arthrotomy for removal of prosthesis without r...
# 21  8053  Repair of the anulus fibrosus with graft or pr...
# 22   813                                  Refusion of spine
# 23    82   Operations on muscle, tendon, and fascia of hand
# 24    83  Operations on muscle, tendon, fascia, and burs...
# 25   887                              Diagnostic ultrasound
#
#                                               include           Code_include  \
# 0                         operations on: pineal gland        0717, 0751-0759
# 1                             Directional atherectomy       1753, 1754, 1755
# 2                           Excimer laser atherectomy       1753, 1754, 1755
# 3                              Rotational atherectomy       1753, 1754, 1755
# 4                                       mastoidectomy                    204
# 5                                       mastoidectomy                    204
# 6                                       mastoidectomy                    204
# 7                                 operations on: lips  0101-0299, 0202, 0353
# 8                                   electrocardiogram                   8952
# 9                                Complete proctectomy                   4869
# 10  reduction with insertion of traction device (K...                   9788
# 11  removal of posterior spinal motion preservatio...                   8009
# 12  removal of posterior spinal motion preservatio...                   8009
# 13  removal of posterior spinal motion preservatio...                   8009
# 14  removal of posterior spinal motion preservatio...                   8009
# 15  removal of posterior spinal motion preservatio...                   8009
# 16  removal of posterior spinal motion preservatio...                   8009
# 17  removal of posterior spinal motion preservatio...                   8009
# 18  removal of posterior spinal motion preservatio...                   8009
# 19  removal of posterior spinal motion preservatio...                   8009
# 20  removal of posterior spinal motion preservatio...                   8009
# 21  microsurgical suture repair with fascial autog...                   8054
# 22              correction of pseudarthrosis of spine             8130- 8139
# 23                         operations on: aponeurosis                   8342
# 24                         operations on: aponeurosis                   8342
# 25                                    Ultrasonography             8874, 8873
#
#                                   Code_include_expand
# 0                  0717, 0751, 0752, 0753, 0754, 0759
# 1                                    1753, 1754, 1755
# 2                                    1753, 1754, 1755
# 3                                    1753, 1754, 1755
# 4                               204, 2041, 2042, 2049
# 5                               204, 2041, 2042, 2049
# 6                               204, 2041, 2042, 2049
# 7   0101, 0102, 0109, 0110, 0111, 0112, 0113, 0114...
# 8                                                8952
# 9                                                4869
# 10                                               9788
# 11                                               8009
# 12                                               8009
# 13                                               8009
# 14                                               8009
# 15                                               8009
# 16                                               8009
# 17                                               8009
# 18                                               8009
# 19                                               8009
# 20                                               8009
# 21                                               8054
# 22  8130, 8131, 8132, 8133, 8134, 8135, 8136, 8137...
# 23                                               8342
# 24                                               8342
# 25                                         8873, 8874
#                                                 include  rank  \
# 0     Atherectomy of other non-coronary vessel(s) Th...     1
# 1     Atherectomy of other non-coronary vessel(s) Th...     2
# 2     Atherectomy of other non-coronary vessel(s) Th...     3
# 3     Atherectomy of other non-coronary vessel(s) Th...     4
# 4     Atherectomy of other non-coronary vessel(s) Th...     5
# ...                                                 ...   ...
# 1185                         with synchronous colostomy     1
# 1186                         with synchronous colostomy     2
# 1187                         with synchronous colostomy     3
# 1188                         with synchronous colostomy     4
# 1189                         with synchronous colostomy     5
#
#                                           matched_title      score  Code  \
# 0           Atherectomy of other non-coronary vessel(s)  99.220181  1756
# 1           atherectomy of other non-coronary vessel(s)  99.220181  1756
# 2     Percutaneous atherectomy of extracranial vesse...  99.136752  1753
# 3     Percutaneous atherectomy of intracranial vesse...  98.991090  1754
# 4           angioplasty of other non-coronary vessel(s)  98.872608  3950
# ...                                                 ...        ...   ...
# 1185  Colostomy that with synchronous anterior recta...  98.625386  4862
# 1186  Other anterior resection of rectum that with s...  98.173892  4862
# 1187  Anterior resection of rectum with synchronous ...  98.001313  4862
# 1188  ureteroureterostomy associated with partial re...  97.645849  5641
# 1189                       Delayed opening of colostomy  97.584957  4614
#
#       IS_MAP
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 1185   False
# 1186   False
# 1187   False
# 1188   False
# 1189   False
#
# [1190 rows x 6 columns]
# Exporting data to ../result/icd9_inclusion_mapping_summary.xlsx...

# %%
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment
from openpyxl.utils import get_column_letter

# 1. Load your existing Excel file
file_path = output_filename
wb = load_workbook(file_path)

print(f"Applying formatting to {file_path}...")

# 2. Loop through all the sheets in your workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]

    # --- BEATIFICATION STEP A: Auto-fit Column Widths ---
    for col in ws.columns:
        max_length = 0
        column = col[0].column_letter # Gets the letter (A, B, C...)
        
        # Find the longest string of text in the entire column
        for cell in col:
            try:
                if len(str(cell.value)) > max_length:
                    max_length = len(str(cell.value))
            except:
                pass
        
        # Add a little padding (+2) and set the new width. 
        # (We cap it at 75 so extremely long inclusion texts don't stretch the screen too far)
        adjusted_width = min(max_length + 2, 75) 
        ws.column_dimensions[column].width = adjusted_width

    # --- BEATIFICATION STEP B: Style the Header Row ---
    # Create a light gray fill and a bold font
    header_fill = PatternFill(start_color="E0E0E0", end_color="E0E0E0", fill_type="solid")
    header_font = Font(bold=True, color="000000")

    # Apply the styling to every cell in the first row
    for cell in ws[1]: 
        cell.font = header_font
        cell.fill = header_fill
        # Center the text and wrap it if it gets too long
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)

    # --- BEATIFICATION STEP C: Highlight IS_MAP = True ---
    # 1. Find which column has the header "IS_MAP"
    is_map_col_idx = None
    for cell in ws[1]:
        if cell.value == "IS_MAP":
            is_map_col_idx = cell.column
            break
            
    # 2. If the column exists in this specific sheet, apply the color
    if is_map_col_idx is not None:
        # Define a nice, readable light green fill
        green_fill = PatternFill(start_color="C6EFCE", end_color="C6EFCE", fill_type="solid")
        
        # Loop through rows in that column (starting at row 2 to skip the header)
        for row in range(2, ws.max_row + 1):
            cell = ws.cell(row=row, column=is_map_col_idx)
            
            # Check if the cell is boolean True or the text "True"
            if cell.value is True or str(cell.value).strip().upper() == "TRUE":
                cell.fill = green_fill

# 3. Save the changes back to the file
wb.save(file_path)
print("Excel file successfully beautified!")
# Out:
# Applying formatting to ../result/icd9_inclusion_mapping_summary.xlsx...
# Excel file successfully beautified!
