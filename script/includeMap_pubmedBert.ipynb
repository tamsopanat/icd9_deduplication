# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

from deduplicate import remove_less_detailed_code

# %%
icd9 = pd.read_json('../data/icd9-cm-2015-code.json').T
icd9 = icd9.reset_index(names="Code")
icd9
# Out:
#       Code   code                                              title  \
# 0       00     00  Procedures and interventions , Not Elsewhere C...
# 1      000   00.0                             Therapeutic ultrasound
# 2     0001  00.01  Therapeutic ultrasound of vessels of head and ...
# 3     0002  00.02                    Therapeutic ultrasound of heart
# 4     0003  00.03  Therapeutic ultrasound of peripheral vascular ...
# ...    ...    ...                                                ...
# 4641  9995  99.95                             Stretching of foreskin
# 4642  9996  99.96    Collection of sperm for artificial insemination
# 4643  9997  99.97                                 Fitting of denture
# 4644  9998  99.98           Extraction of milk from lactating breast
# 4645  9999  99.99                                              Other
#
#                                                 exclude  sex  \
# 0                                                   NaN  NaN
# 1     [diagnostic ultrasound (non-invasive) (88.71-8...  NaN
# 2     [diagnostic ultrasound of: eye (95.13), diagno...    B
# 3     [diagnostic ultrasound of heart (88.72), ultra...    B
# 4     [diagnostic ultrasound of peripheral vascular ...    B
# ...                                                 ...  ...
# 4641                                                NaN    B
# 4642                                                NaN    M
# 4643                                                NaN    B
# 4644                                                NaN    F
# 4645                                                NaN    B
#
#                                                 synonym include codeAlso note  \
# 0                                                   NaN     NaN      NaN  NaN
# 1                                                   NaN     NaN      NaN  NaN
# 2     [Anti-restenotic ultrasound, Intravascular non...     NaN      NaN  NaN
# 3     [Anti-restenotic ultrasound, Intravascular non...     NaN      NaN  NaN
# 4     [Anti-restenotic ultrasound, Intravascular non...     NaN      NaN  NaN
# ...                                                 ...     ...      ...  ...
# 4641                                                NaN     NaN      NaN  NaN
# 4642                                                NaN     NaN      NaN  NaN
# 4643                                                NaN     NaN      NaN  NaN
# 4644                                                NaN     NaN      NaN  NaN
# 4645                                    [Leech therapy]     NaN      NaN  NaN
#
#      fourth-digit
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4641          NaN
# 4642          NaN
# 4643          NaN
# 4644          NaN
# 4645          NaN
#
# [4646 rows x 10 columns]

# %%
with open('../data/index_icd9.json') as f:
    icd9_index = json.load(f)

def flatten_nodes(node, parent_terms=None):
    if parent_terms is None:
        parent_terms = []
        
    rows = []
    # Combine parent terms with the current node's term
    current_terms = parent_terms + [node.get('term', '')]
    full_term = " ".join(current_terms).strip()
    
    # Append the current node data
    rows.append({
        'term': full_term,
        'code': node.get('code', None)
    })
    
    # Recurse down into any children
    for child in node.get('children', []):
        rows.extend(flatten_nodes(child, current_terms))
        
    return rows

icd9_index_df = []
for item in icd9_index:
    icd9_index_df.extend(flatten_nodes(item))

icd9_index_df = pd.DataFrame(icd9_index_df)
icd9_index_df = icd9_index_df.dropna()
icd9_index_df['Code'] = icd9_index_df['code'].str.replace('.','')
icd9_index_df['Code'] = icd9_index_df['Code'].str.findall(r"\d+")
icd9_index_df
# Out:
#                                                     term   code    Code
# 1                  Abbe operation construction of vagina  70.61  [7061]
# 2      Abbe operation construction of vagina with gra...  70.63  [7063]
# 4                                    Abciximab, infusion  99.20  [9920]
# 5                                       Abdominocentesis  54.91  [5491]
# 6                                   Abdominohysterectomy  68.49  [6849]
# ...                                                  ...    ...     ...
# 20704                                Z-plasty epicanthus  08.59  [0859]
# 20705  Z-plasty eyelid --see also Reconstruction, eyelid  08.70  [0870]
# 20706                               Z-plasty hypopharynx   29.4   [294]
# 20707             Z-plasty skin (scar) (web contracture)  86.84  [8684]
# 20708  Z-plasty skin (scar) (web contracture) with ex...   86.3   [863]
#
# [17113 rows x 3 columns]

# %% [markdown]
# ### if code is already exist in other code inclusion then remove

# %%
# Map from inclusion to icd9 for defining including icd9 code
# Prepare all name of icd9 from title, synonym, and index
title = icd9[["Code", "title"]].copy()
title = title.groupby("title", as_index=False).agg(list)
title['Code'] = title['Code'].apply(remove_less_detailed_code)
display(title.query("title == 'Other'"))
title = title[title['title'] != 'Other'].copy()
print("Remove title = 'Other'")
title
# Out:
# Removed: '512' (Reason: Less detailed version of '5122')
# Removed: '148' (Reason: Less detailed version of '1481')
# Removed: '992' (Reason: Less detailed version of '9929')
# Removed: '663' (Reason: Less detailed version of '6639')
# Removed: '136' (Reason: Less detailed version of '1369')
# Removed: '823' (Reason: Less detailed version of '8239')
# Removed: '673' (Reason: Less detailed version of '6739')
# Removed: '135' (Reason: Less detailed version of '1359')
# Removed: '363' (Reason: Less detailed version of '3639')
# Removed: '935' (Reason: Less detailed version of '9359')
# Removed: '75' (Reason: Less detailed version of '759')
# Removed: '04' (Reason: Less detailed version of '049')
# Removed: '37' (Reason: Less detailed version of '379')
# Removed: '09' (Reason: Less detailed version of '099')
# Removed: '31' (Reason: Less detailed version of '319')
# Removed: '33' (Reason: Less detailed version of '339')
# Removed: '20' (Reason: Less detailed version of '2099')
# Removed: '27' (Reason: Less detailed version of '279')
# Removed: '829' (Reason: Less detailed version of '8299')
# Removed: '839' (Reason: Less detailed version of '8399')
# Removed: '02' (Reason: Less detailed version of '029')
# Removed: '44' (Reason: Less detailed version of '449')
# Removed: '399' (Reason: Less detailed version of '3999')
# Removed: '39' (Reason: Less detailed version of '3999')
# Removed: '369' (Reason: Less detailed version of '3699')
# Removed: '302' (Reason: Less detailed version of '3029')
# Removed: '828' (Reason: Less detailed version of '8289')
# Removed: '187' (Reason: Less detailed version of '1879')
# Removed: '868' (Reason: Less detailed version of '8689')
# Removed: '676' (Reason: Less detailed version of '6769')
# Removed: '428' (Reason: Less detailed version of '4289')
# Removed: '467' (Reason: Less detailed version of '4679')
# Removed: '707' (Reason: Less detailed version of '7079')
# Removed: '995' (Reason: Less detailed version of '9959')
# Removed: '881' (Reason: Less detailed version of '8819')
# Removed: '405' (Reason: Less detailed version of '4059')
# Removed: '705' (Reason: Less detailed version of '7050')
# Removed: '756' (Reason: Less detailed version of '7569')
# Removed: '572' (Reason: Less detailed version of '5721')
#       title                                               Code
# 2408  Other  [0299, 0399, 0499, 0589, 0639, 0749, 0779, 085...
# Remove title = 'Other'
#                                                   title    Code
# 0     (Aorto)coronary bypass of four or more coronar...  [3614]
# 1         (Aorto)coronary bypass of one coronary artery  [3611]
# 2     (Aorto)coronary bypass of three coronary arteries  [3613]
# 3       (Aorto)coronary bypass of two coronary arteries  [3612]
# 4     (Laparoscopic) adjustment of size of adjustabl...  [4498]
# ...                                                 ...     ...
# 4534                            X-ray of urinary system   [877]
# 4535                                 X-ray study of eye  [9514]
# 4536                       X-ray, other and unspecified  [8839]
# 4537                               Xerography of breast  [8736]
# 4538                 [Endoscopic] polypectomy of rectum  [4836]
#
# [4538 rows x 2 columns]

# %%
syn = icd9[["Code", "synonym"]].copy().explode("synonym").dropna()
syn = syn.rename(columns={"synonym": "title"})
print("Remove title = '(99.77)'")
syn = syn[syn['title'] != '(99.77)'].copy()
syn = syn.groupby(["title"], as_index=False).agg(list)
syn['Code'] = syn['Code'].apply(remove_less_detailed_code)

syn
# Out:
# Remove title = '(99.77)'
# Removed: '176' (Reason: Less detailed version of '1761')
# Removed: '684' (Reason: Less detailed version of '6849')
#                                                   title    Code
# 0           "Cocked-hat" procedure [skin flap and bone]  [8269]
# 1                                 14 C-Urea breath test  [8939]
# 2                    Abbreviated history and evaluation  [8901]
# 3                         Abdominoperineal pull-through  [4849]
# 4              Ablation (contact) (noncontact) by laser  [6021]
# ...                                                 ...     ...
# 4037  percutaneous transluminal coronary angioplasty...  [3607]
# 4038            procedure on vessel bifurcation (00.44)  [3607]
# 4039                            stabilization device(s)  [8483]
# 4040          transluminal coronary atherectomy (17.55)  [3607]
# 4041                                       vascular NOS  [3929]
#
# [4042 rows x 2 columns]

# %%
index = icd9_index_df[["Code", "term"]].copy().rename(columns={"term": "title"})
index = index.groupby(["title"], as_index=False).agg(lambda x: x.sum())
index['Code'] = index['Code'].apply(set).apply(remove_less_detailed_code)
index
# Out:
# Removed: '783' (Reason: Less detailed version of '7839')
#                                                    title    Code
# 0      AESOP (Automated Endoscopic System for Optimal...   [174]
# 1                  Abbe operation construction of vagina  [7061]
# 2      Abbe operation construction of vagina with gra...  [7063]
# 3                                    Abciximab, infusion  [9920]
# 4                                       Abdominocentesis  [5491]
# ...                                                  ...     ...
# 16363  through previously implanted catheter or reser...  [0102]
# 16364        transsphenoidal approach (complete) (total)  [0765]
# 16365  transsphenoidal approach (complete) (total) pa...  [0762]
# 16366                 von Kraske operation (proctectomy)  [4864]
# 16367                             with incus replacement  [1911]
#
# [16368 rows x 2 columns]

# %%
main = pd.concat([title, syn, index], ignore_index=True)
cleaning_patterns = {
    r'^\s*\[[\d\-]+\]\s*': ' ',                # Wipes bracketed prefixes e.g. [0-9]
    r'\s*\(\d+(?:\.\d+)?\)\s*': ' ',           # Wipes parenthetical codes e.g. (42.91)
    r'[()\[\]]': '',                           # Strips literal brackets and parentheses
    r':|"|\bNOS\b|\bNEC\b|--see also\b|--see category\b|--seecategory\b|--see categories\b|--see\b': '',
    r'\s+': ' '                                # Collapses multi-spaces down to a single space
}

# Apply all regex cleanups iteratively on the original "title" column
clean_titles = main["title"].copy()
for pattern, replacement in cleaning_patterns.items():
    clean_titles = clean_titles.str.replace(pattern, replacement, regex=True)

main["clean_title"] = clean_titles.str.strip()

main = main.groupby(['title','clean_title'], as_index = False).agg(lambda x: x.sum())
main['Code'] = main['Code'].apply(set).apply(remove_less_detailed_code)
main.drop_duplicates(subset=['clean_title'], keep='first', inplace=True)
main
# Out:
# Removed: '802' (Reason: Less detailed version of '8020')
# Removed: '730' (Reason: Less detailed version of '7309')
# Removed: '104' (Reason: Less detailed version of '1049')
# Removed: '020' (Reason: Less detailed version of '0206')
# Removed: '380' (Reason: Less detailed version of '3800')
# Removed: '450' (Reason: Less detailed version of '4500')
# Removed: '421' (Reason: Less detailed version of '4210')
# Removed: '462' (Reason: Less detailed version of '4620')
# Removed: '650' (Reason: Less detailed version of '6509')
# Removed: '787' (Reason: Less detailed version of '7870')
# Removed: '276' (Reason: Less detailed version of '2769')
# Removed: '520' (Reason: Less detailed version of '5209')
# Removed: '650' (Reason: Less detailed version of '6509')
# Removed: '191' (Reason: Less detailed version of '1919')
# Removed: '923' (Reason: Less detailed version of '9230')
# Removed: '888' (Reason: Less detailed version of '8889')
# Removed: '380' (Reason: Less detailed version of '3800')
# Removed: '078' (Reason: Less detailed version of '0780')
# Removed: '564' (Reason: Less detailed version of '5640')
#                                                    title  \
# 0            "Cocked-hat" procedure [skin flap and bone]
# 1      (Aorto)coronary bypass of four or more coronar...
# 2          (Aorto)coronary bypass of one coronary artery
# 3      (Aorto)coronary bypass of three coronary arteries
# 4        (Aorto)coronary bypass of two coronary arteries
# ...                                                  ...
# 24660        transsphenoidal approach (complete) (total)
# 24661  transsphenoidal approach (complete) (total) pa...
# 24662                                       vascular NOS
# 24663                 von Kraske operation (proctectomy)
# 24664                             with incus replacement
#
#                                              clean_title    Code
# 0                Cocked-hat procedure skin flap and bone  [8269]
# 1      Aortocoronary bypass of four or more coronary ...  [3614]
# 2            Aortocoronary bypass of one coronary artery  [3611]
# 3        Aortocoronary bypass of three coronary arteries  [3613]
# 4          Aortocoronary bypass of two coronary arteries  [3612]
# ...                                                  ...     ...
# 24660            transsphenoidal approach complete total  [0765]
# 24661    transsphenoidal approach complete total partial  [0762]
# 24662                                           vascular  [3929]
# 24663                   von Kraske operation proctectomy  [4864]
# 24664                             with incus replacement  [1911]
#
# [24557 rows x 3 columns]

# %%
main['title'].nunique(), main['clean_title'].nunique()
# Out:
# (24557, 24557)

# %%
inc = icd9[["Code", "title", "include"]].copy().explode("include").dropna()
inc['clean_include'] = inc['include'].str.replace(r'[()\[\]]', '', regex=True)
inc["clean_include"] = inc["clean_include"].str.replace(':|NOS','', regex=True)
inc['clean_include'] = inc['clean_include'].str.replace(r'\s+', ' ', regex=True).str.strip()
inc
# Out:
#       Code                                              title  \
# 15    0018     Infusion of immunosuppressive antibody therapy
# 15    0018     Infusion of immunosuppressive antibody therapy
# 15    0018     Infusion of immunosuppressive antibody therapy
# 53    0059  Intravascular pressure measurement of coronary...
# 58    0063  Percutaneous insertion of carotid artery stent(s)
# ...    ...                                                ...
# 4560   991  Injection or infusion of therapeutic or prophy...
# 4560   991  Injection or infusion of therapeutic or prophy...
# 4571   992  Injection or infusion of other therapeutic or ...
# 4571   992  Injection or infusion of other therapeutic or ...
# 4571   992  Injection or infusion of other therapeutic or ...
#
#                                                 include  \
# 15    during induction phase of solid organ transpla...
# 15                          monoclonal antibody therapy
# 15                          polyclonal antibody therapy
# 53                        fractional flow reserve (FFR)
# 58    the use of any embolic protection device, dist...
# ...                                                 ...
# 4560  injection or infusion given: intramuscularly a...
# 4560  injection or infusion given: intravenously act...
# 4571  injection or infusion given: hypodermically ac...
# 4571  injection or infusion given: intramuscularly a...
# 4571  injection or infusion given: intravenously act...
#
#                                           clean_include
# 15    during induction phase of solid organ transpla...
# 15                          monoclonal antibody therapy
# 15                          polyclonal antibody therapy
# 53                          fractional flow reserve FFR
# 58    the use of any embolic protection device, dist...
# ...                                                 ...
# 4560  injection or infusion given intramuscularly ac...
# 4560  injection or infusion given intravenously acti...
# 4571  injection or infusion given hypodermically act...
# 4571  injection or infusion given intramuscularly ac...
# 4571  injection or infusion given intravenously acti...
#
# [277 rows x 4 columns]

# %%
from sentence_transformers import SentenceTransformer, util

# 1. Load the model 
print("Loading Transformer model...")
model = SentenceTransformer('microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext') # This model was previously named "PubMedBERT (abstracts + full text)".

# 2. Prepare the arrays
choices = main["clean_title"].dropna().unique()
queries = inc['clean_include'].dropna().unique()

# 3. Convert text to embeddings (Vectors)
# show_progress_bar=True will give you a nice visual of the encoding speed
print(f"Encoding {len(choices)} target choices into vectors...")
corpus_embeddings = model.encode(choices, convert_to_tensor=True, show_progress_bar=True)

print(f"Encoding {len(queries)} query inclusions into vectors...")
query_embeddings = model.encode(queries, convert_to_tensor=True, show_progress_bar=True)

# 4. Calculate Cosine Similarity
print("Calculating top 5 matches via Cosine Similarity...")
hits = util.semantic_search(query_embeddings, corpus_embeddings, top_k=5)

results = []
for query_idx, hit_list in enumerate(hits):
    query_text = queries[query_idx]
    for rank, hit in enumerate(hit_list, start=1):
        matched_title = choices[hit['corpus_id']]
        score = min(100, hit['score'] * 100)
        
        results.append({
            "include": query_text,
            "rank": rank,
            "matched_title": matched_title,
            "score": score
        })

top5_df = pd.DataFrame(results)
top5_df
# Out:
# Loading Transformer model...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Encoding 24557 target choices into vectors...
# Batches:   0%|          | 0/768 [00:00<?, ?it/s]
# Encoding 238 query inclusions into vectors...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating top 5 matches via Cosine Similarity...
#                                                 include  rank  \
# 0     during induction phase of solid organ transpla...     1
# 1     during induction phase of solid organ transpla...     2
# 2     during induction phase of solid organ transpla...     3
# 3     during induction phase of solid organ transpla...     4
# 4     during induction phase of solid organ transpla...     5
# ...                                                 ...   ...
# 1185  injection or infusion given intravenously acti...     1
# 1186  injection or infusion given intravenously acti...     2
# 1187  injection or infusion given intravenously acti...     3
# 1188  injection or infusion given intravenously acti...     4
# 1189  injection or infusion given intravenously acti...     5
#
#                                           matched_title      score
# 0     Formation of peripheral arteriovenous fistula ...  97.031879
# 1        Allogeneic bone marrow transplant with purging  97.026950
# 2     Allograft of bone marrow with in vitro removal...  96.948200
# 3             Puncture donor for bone marrow transplant  96.933234
# 4     Extracorporeal circulation auxiliary to open h...  96.897918
# ...                                                 ...        ...
# 1185  Introduction therapeutic substance acting loca...  98.052579
# 1186  Injection or infusion of therapeutic or prophy...  97.694868
# 1187  Injection of locally-acting therapeutic substa...  97.576594
# 1188  Injection of locally-acting therapeutic substa...  97.557235
# 1189  Introduction therapeutic substance acting loca...  97.484219
#
# [1190 rows x 4 columns]

# %%
rank1_df = top5_df.query('rank == 1')
P = 75 # Increase for higher confidence, and vice versa.
threshold = np.percentile(rank1_df['score'], P)

fig, ax = plt.subplots(figsize=(12, 4))
sns.histplot(
    data=rank1_df, 
    x="score", 
    bins=30,
    ax=ax
)

ax.axvline(x=threshold, color='red', linestyle='--', linewidth=2, label=f'{P}th Percentile Threshold ({threshold:.3f})')

ax.set_title("Distribution of Scores (Rank 1)", fontsize=12)
ax.set_xlabel("TF-IDF Cosine Similarity", fontsize=12)
ax.set_ylabel("Number of Inclusion Texts", fontsize=12)
ax.legend()

plt.tight_layout()
plt.show()

# %%
cutoff_res = top5_df.query(f'score >= {threshold}')

mapped_count = len(cutoff_res['include'].unique())
total_count = len(queries)
print(f"Successfully Mapped: {mapped_count / total_count:.2%} ({mapped_count} out of {total_count} inclusions)")

cutoff_res = cutoff_res.merge(main, left_on='matched_title', right_on='clean_title', how='left')
cutoff_res = cutoff_res.drop(columns = ["clean_title"])
cutoff_res
# Out:
# Successfully Mapped: 25.21% (60 out of 238 inclusions)
#                                                include  rank  \
# 0                          fractional flow reserve FFR     1
# 1             Intra-operative neurophysiologic testing     1
# 2                           operations on pineal gland     1
# 3                           operations on pineal gland     2
# 4                                 operations on thymus     1
# ..                                                 ...   ...
# 138  Fat graft of skin and subcutaneous tissue with...     1
# 139                 venography using contrast material     1
# 140                 venography using contrast material     2
# 141                Endotracheal respiratory assistance     1
# 142  BiPAP delivered through endotracheal tube or t...     1
#
#                                          matched_title      score  \
# 0              Measurement fractional flow reserve FFR  99.123001
# 1          Intra-operative neurophysiologic monitoring  99.491405
# 2                           Operations on pineal gland  99.999982
# 3                     Other operations on pineal gland  99.270648
# 4                                 Operations on cornea  99.167633
# ..                                                 ...        ...
# 138          Fat graft of skin and subcutaneous tissue  98.900402
# 139              Arteriography using contrast material  99.503207
# 140          Angiocardiography using contrast material  98.942763
# 141    Ventilation endotracheal respiratory assistance  98.930043
# 142  BiPAP without delivery through endotracheal tu...  98.963636
#
#                                                  title    Code
# 0            Measurement fractional flow reserve (FFR)  [0059]
# 1          Intra-operative neurophysiologic monitoring  [0094]
# 2                           Operations on pineal gland   [075]
# 3                     Other operations on pineal gland  [0759]
# 4                                 Operations on cornea    [11]
# ..                                                 ...     ...
# 138          Fat graft of skin and subcutaneous tissue  [8687]
# 139              Arteriography using contrast material   [884]
# 140          Angiocardiography using contrast material   [885]
# 141  Ventilation endotracheal respiratory assistanc...   [967]
# 142  BiPAP without (delivery through) endotracheal ...  [9390]
#
# [143 rows x 6 columns]

# %%
inc_map = cutoff_res[["Code", "include"]]
print(f"Successfully Mapped: {len(inc_map['include'].unique()) / len(queries):.2%} ({len(inc_map['include'].unique())} out of {len(queries)} inclusions)")
inc_map
# Out:
# Successfully Mapped: 25.21% (60 out of 238 inclusions)
#        Code                                            include
# 0    [0059]                        fractional flow reserve FFR
# 1    [0094]           Intra-operative neurophysiologic testing
# 2     [075]                         operations on pineal gland
# 3    [0759]                         operations on pineal gland
# 4      [11]                               operations on thymus
# ..      ...                                                ...
# 138  [8687]  Fat graft of skin and subcutaneous tissue with...
# 139   [884]                 venography using contrast material
# 140   [885]                 venography using contrast material
# 141   [967]                Endotracheal respiratory assistance
# 142  [9390]  BiPAP delivered through endotracheal tube or t...
#
# [143 rows x 2 columns]

# %%
inc_map_df = inc.merge(inc_map, left_on='clean_include', right_on='include', how='left', suffixes=('', '_include'))
inc_map_df = inc_map_df.drop(columns = ["clean_include", "include_include"])
inc_map_df = inc_map_df.explode('Code_include')
inc_map_df = inc_map_df.query("Code != Code_include") # Exclude map include to self
inc_map_df = inc_map_df.drop_duplicates()
inc_map_df = inc_map_df.dropna()
inc_map_df = inc_map_df.groupby(['Code', 'title', 'include'], as_index=False).agg(list)
inc_map_df['Code_include'] = inc_map_df['Code_include'].apply(remove_less_detailed_code)
inc_map_df
# Out:
# Removed: '075' (Reason: Less detailed version of '0759')
# Removed: '204' (Reason: Less detailed version of '2041')
# Removed: '204' (Reason: Less detailed version of '2041')
# Removed: '204' (Reason: Less detailed version of '2041')
# Removed: '518' (Reason: Less detailed version of '5189')
#     Code                                              title  \
# 0     07               Operations on other endocrine glands
# 1     07               Operations on other endocrine glands
# 2    142        Destruction of lesion of retina and choroid
# 3   1756        Atherectomy of other non-coronary vessel(s)
# 4   1756        Atherectomy of other non-coronary vessel(s)
# 5   1756        Atherectomy of other non-coronary vessel(s)
# 6   1756        Atherectomy of other non-coronary vessel(s)
# 7   1756        Atherectomy of other non-coronary vessel(s)
# 8   2096  Implantation or replacement of cochlear prosth...
# 9   2097  Implantation or replacement of cochlear prosth...
# 10  2098  Implantation or replacement of cochlear prosth...
# 11   226                            Other nasal sinusectomy
# 12    26            Operations on salivary glands and ducts
# 13    26            Operations on salivary glands and ducts
# 14    27                 Other operations on mouth and face
# 15    27                 Other operations on mouth and face
# 16  3521  Open and other replacement of aortic valve wit...
# 17  3521  Open and other replacement of aortic valve wit...
# 18  3521  Open and other replacement of aortic valve wit...
# 19  3523  Open and other replacement of mitral valve wit...
# 20  3523  Open and other replacement of mitral valve wit...
# 21  3523  Open and other replacement of mitral valve wit...
# 22  3525  Open and other replacement of pulmonary valve ...
# 23  3525  Open and other replacement of pulmonary valve ...
# 24  3525  Open and other replacement of pulmonary valve ...
# 25  3527  Open and other replacement of tricuspid valve ...
# 26  3527  Open and other replacement of tricuspid valve ...
# 27  3527  Open and other replacement of tricuspid valve ...
# 28  3897    Central venous catheter placement with guidance
# 29   460                       Exteriorization of intestine
# 30   485               Abdominoperineal resection of rectum
# 31    51        Operations on gallbladder and biliary tract
# 32    51        Operations on gallbladder and biliary tract
# 33    53                                   Repair of hernia
# 34    54               Other operations on abdominal region
# 35    54               Other operations on abdominal region
# 36    55                               Operations on kidney
# 37   662  Bilateral endoscopic destruction or occlusion ...
# 38   662  Bilateral endoscopic destruction or occlusion ...
# 39   662  Bilateral endoscopic destruction or occlusion ...
# 40   662  Bilateral endoscopic destruction or occlusion ...
# 41   663  Other bilateral destruction or occlusion of fa...
# 42  6825    Uterine artery embolization [UAE] without coils
# 43    79              Reduction of fracture and dislocation
# 44    80          Incision and excision of joint structures
# 45  8053  Repair of the anulus fibrosus with graft or pr...
# 46  8460  Insertion of spinal disc prosthesis, not other...
# 47  8461  Insertion of partial spinal disc prosthesis, c...
# 48  8462  Insertion of total spinal disc prosthesis, cer...
# 49  8463      Insertion of spinal disc prosthesis, thoracic
# 50  8464  Insertion of partial spinal disc prosthesis, l...
# 51  8465  Insertion of total spinal disc prosthesis, lum...
# 52   866                                    Free skin graft
# 53   886                                       Phlebography
# 54   967   Other continuous invasive mechanical ventilation
#
#                                               include  \
# 0                         operations on: pineal gland
# 1                               operations on: thymus
# 2   destruction of chorioretinopathy or isolated c...
# 3   Atherectomy of other non-coronary vessel(s) Th...
# 4   Atherectomy of other non-coronary vessel(s) Th...
# 5                             Directional atherectomy
# 6                           Excimer laser atherectomy
# 7                              Rotational atherectomy
# 8                                       mastoidectomy
# 9                                       mastoidectomy
# 10                                      mastoidectomy
# 11  Other nasal sinusectomy that with incidental t...
# 12      operations on: lesser salivary gland and duct
# 13              operations on: parotid gland and duct
# 14                                operations on: lips
# 15                              operations on: palate
# 16  Open and other replacement of aortic valve wit...
# 17  Open and other replacement of aortic valve wit...
# 18  Open and other replacement of aortic valve wit...
# 19  Open and other replacement of mitral valve wit...
# 20  Open and other replacement of mitral valve wit...
# 21  Open and other replacement of mitral valve wit...
# 22  Open and other replacement of pulmonary valve ...
# 23  Open and other replacement of pulmonary valve ...
# 24  Open and other replacement of pulmonary valve ...
# 25  Open and other replacement of tricuspid valve ...
# 26  Open and other replacement of tricuspid valve ...
# 27  Open and other replacement of tricuspid valve ...
# 28                                  electrocardiogram
# 29                                   loop enterostomy
# 30                               Complete proctectomy
# 31                        operations on: hepatic duct
# 32                   operations on: sphincter of Oddi
# 33                                      herniorrhaphy
# 34                               operations on: flank
# 35                          operations on: peritoneum
# 36                         operations on renal pelvis
# 37  bilateral endoscopic destruction or occlusion ...
# 38  bilateral endoscopic destruction or occlusion ...
# 39  bilateral endoscopic destruction or occlusion ...
# 40  bilateral endoscopic destruction or occlusion ...
# 41             destruction of solitary fallopian tube
# 42  Uterine artery embolization [UAE] without coil...
# 43                      application of cast or splint
# 44                             operations on: condyle
# 45  microsurgical suture repair with fascial autog...
# 46                            diskectomy (discectomy)
# 47                            diskectomy (discectomy)
# 48                            diskectomy (discectomy)
# 49                            diskectomy (discectomy)
# 50                            diskectomy (discectomy)
# 51                            diskectomy (discectomy)
# 52              excision of skin for autogenous graft
# 53                 venography using contrast material
# 54  BiPAP delivered through endotracheal tube or t...
#
#                 Code_include
# 0                     [0759]
# 1        [0141, 147, 11, 56]
# 2                     [1429]
# 3                     [1753]
# 4               [1753, 1754]
# 5         [1755, 1754, 1753]
# 6         [1755, 1754, 1753]
# 7         [1755, 1754, 1753]
# 8   [2041, 2092, 2042, 2049]
# 9   [2041, 2092, 2042, 2049]
# 10  [2041, 2092, 2042, 2049]
# 11                    [2260]
# 12                     [269]
# 13                     [269]
# 14                      [25]
# 15                      [25]
# 16  [3525, 3523, 3520, 3527]
# 17  [3520, 3525, 3523, 3527]
# 18  [3520, 3525, 3523, 3527]
# 19  [3525, 3521, 3527, 3520]
# 20  [3521, 3520, 3525, 3527]
# 21  [3521, 3525, 3520, 3527]
# 22  [3527, 3523, 3521, 3520]
# 23  [3520, 3521, 3523, 3527]
# 24  [3521, 3520, 3527, 3523]
# 25  [3525, 3523, 3521, 3520]
# 26  [3525, 3521, 3523, 3520]
# 27  [3525, 3521, 3523, 3520]
# 28                    [8952]
# 29        [4601, 4603, 4639]
# 30          [4869, 576, 481]
# 31                      [50]
# 32                    [5189]
# 33        [5300, 4673, 4675]
# 34       [0141, 147, 11, 56]
# 35                      [65]
# 36                      [57]
# 37                    [6629]
# 38        [6622, 6621, 6629]
# 39        [6629, 6622, 6621]
# 40                    [6629]
# 41                    [6652]
# 42                    [6824]
# 43                    [9354]
# 44           [0141, 147, 11]
# 45                    [8054]
# 46                    [8051]
# 47                    [8051]
# 48                    [8051]
# 49                    [8051]
# 50                    [8051]
# 51                    [8051]
# 52                    [8691]
# 53                [884, 885]
# 54                    [9390]

# %%
output_filename = "../result/icd9_inclusion_mapping_summary_PubMedBERT.xlsx"
print(f"Exporting data to {output_filename}...")

icd9_inc_export = inc_map_df.copy()
list_val_cols = ["Code_include"]

for c in list_val_cols:
    icd9_inc_export[c] = icd9_inc_export[c].apply(
        lambda x: ', '.join([str(i) for i in x]) if isinstance(x, list) else x
    )
display(icd9_inc_export)

with pd.ExcelWriter(output_filename, engine='xlsxwriter') as writer:
    icd9_inc_export.to_excel(writer, sheet_name='Inclusion Mapping', index=False)
# Out:
# Exporting data to ../result/icd9_inclusion_mapping_summary_PubMedBERT.xlsx...
#     Code                                              title  \
# 0     07               Operations on other endocrine glands
# 1     07               Operations on other endocrine glands
# 2    142        Destruction of lesion of retina and choroid
# 3   1756        Atherectomy of other non-coronary vessel(s)
# 4   1756        Atherectomy of other non-coronary vessel(s)
# 5   1756        Atherectomy of other non-coronary vessel(s)
# 6   1756        Atherectomy of other non-coronary vessel(s)
# 7   1756        Atherectomy of other non-coronary vessel(s)
# 8   2096  Implantation or replacement of cochlear prosth...
# 9   2097  Implantation or replacement of cochlear prosth...
# 10  2098  Implantation or replacement of cochlear prosth...
# 11   226                            Other nasal sinusectomy
# 12    26            Operations on salivary glands and ducts
# 13    26            Operations on salivary glands and ducts
# 14    27                 Other operations on mouth and face
# 15    27                 Other operations on mouth and face
# 16  3521  Open and other replacement of aortic valve wit...
# 17  3521  Open and other replacement of aortic valve wit...
# 18  3521  Open and other replacement of aortic valve wit...
# 19  3523  Open and other replacement of mitral valve wit...
# 20  3523  Open and other replacement of mitral valve wit...
# 21  3523  Open and other replacement of mitral valve wit...
# 22  3525  Open and other replacement of pulmonary valve ...
# 23  3525  Open and other replacement of pulmonary valve ...
# 24  3525  Open and other replacement of pulmonary valve ...
# 25  3527  Open and other replacement of tricuspid valve ...
# 26  3527  Open and other replacement of tricuspid valve ...
# 27  3527  Open and other replacement of tricuspid valve ...
# 28  3897    Central venous catheter placement with guidance
# 29   460                       Exteriorization of intestine
# 30   485               Abdominoperineal resection of rectum
# 31    51        Operations on gallbladder and biliary tract
# 32    51        Operations on gallbladder and biliary tract
# 33    53                                   Repair of hernia
# 34    54               Other operations on abdominal region
# 35    54               Other operations on abdominal region
# 36    55                               Operations on kidney
# 37   662  Bilateral endoscopic destruction or occlusion ...
# 38   662  Bilateral endoscopic destruction or occlusion ...
# 39   662  Bilateral endoscopic destruction or occlusion ...
# 40   662  Bilateral endoscopic destruction or occlusion ...
# 41   663  Other bilateral destruction or occlusion of fa...
# 42  6825    Uterine artery embolization [UAE] without coils
# 43    79              Reduction of fracture and dislocation
# 44    80          Incision and excision of joint structures
# 45  8053  Repair of the anulus fibrosus with graft or pr...
# 46  8460  Insertion of spinal disc prosthesis, not other...
# 47  8461  Insertion of partial spinal disc prosthesis, c...
# 48  8462  Insertion of total spinal disc prosthesis, cer...
# 49  8463      Insertion of spinal disc prosthesis, thoracic
# 50  8464  Insertion of partial spinal disc prosthesis, l...
# 51  8465  Insertion of total spinal disc prosthesis, lum...
# 52   866                                    Free skin graft
# 53   886                                       Phlebography
# 54   967   Other continuous invasive mechanical ventilation
#
#                                               include            Code_include
# 0                         operations on: pineal gland                    0759
# 1                               operations on: thymus       0141, 147, 11, 56
# 2   destruction of chorioretinopathy or isolated c...                    1429
# 3   Atherectomy of other non-coronary vessel(s) Th...                    1753
# 4   Atherectomy of other non-coronary vessel(s) Th...              1753, 1754
# 5                             Directional atherectomy        1755, 1754, 1753
# 6                           Excimer laser atherectomy        1755, 1754, 1753
# 7                              Rotational atherectomy        1755, 1754, 1753
# 8                                       mastoidectomy  2041, 2092, 2042, 2049
# 9                                       mastoidectomy  2041, 2092, 2042, 2049
# 10                                      mastoidectomy  2041, 2092, 2042, 2049
# 11  Other nasal sinusectomy that with incidental t...                    2260
# 12      operations on: lesser salivary gland and duct                     269
# 13              operations on: parotid gland and duct                     269
# 14                                operations on: lips                      25
# 15                              operations on: palate                      25
# 16  Open and other replacement of aortic valve wit...  3525, 3523, 3520, 3527
# 17  Open and other replacement of aortic valve wit...  3520, 3525, 3523, 3527
# 18  Open and other replacement of aortic valve wit...  3520, 3525, 3523, 3527
# 19  Open and other replacement of mitral valve wit...  3525, 3521, 3527, 3520
# 20  Open and other replacement of mitral valve wit...  3521, 3520, 3525, 3527
# 21  Open and other replacement of mitral valve wit...  3521, 3525, 3520, 3527
# 22  Open and other replacement of pulmonary valve ...  3527, 3523, 3521, 3520
# 23  Open and other replacement of pulmonary valve ...  3520, 3521, 3523, 3527
# 24  Open and other replacement of pulmonary valve ...  3521, 3520, 3527, 3523
# 25  Open and other replacement of tricuspid valve ...  3525, 3523, 3521, 3520
# 26  Open and other replacement of tricuspid valve ...  3525, 3521, 3523, 3520
# 27  Open and other replacement of tricuspid valve ...  3525, 3521, 3523, 3520
# 28                                  electrocardiogram                    8952
# 29                                   loop enterostomy        4601, 4603, 4639
# 30                               Complete proctectomy          4869, 576, 481
# 31                        operations on: hepatic duct                      50
# 32                   operations on: sphincter of Oddi                    5189
# 33                                      herniorrhaphy        5300, 4673, 4675
# 34                               operations on: flank       0141, 147, 11, 56
# 35                          operations on: peritoneum                      65
# 36                         operations on renal pelvis                      57
# 37  bilateral endoscopic destruction or occlusion ...                    6629
# 38  bilateral endoscopic destruction or occlusion ...        6622, 6621, 6629
# 39  bilateral endoscopic destruction or occlusion ...        6629, 6622, 6621
# 40  bilateral endoscopic destruction or occlusion ...                    6629
# 41             destruction of solitary fallopian tube                    6652
# 42  Uterine artery embolization [UAE] without coil...                    6824
# 43                      application of cast or splint                    9354
# 44                             operations on: condyle           0141, 147, 11
# 45  microsurgical suture repair with fascial autog...                    8054
# 46                            diskectomy (discectomy)                    8051
# 47                            diskectomy (discectomy)                    8051
# 48                            diskectomy (discectomy)                    8051
# 49                            diskectomy (discectomy)                    8051
# 50                            diskectomy (discectomy)                    8051
# 51                            diskectomy (discectomy)                    8051
# 52              excision of skin for autogenous graft                    8691
# 53                 venography using contrast material                884, 885
# 54  BiPAP delivered through endotracheal tube or t...                    9390

# %%
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment
from openpyxl.utils import get_column_letter

# 1. Load your existing Excel file
file_path = output_filename
wb = load_workbook(file_path)

print(f"Applying formatting to {file_path}...")

# 2. Loop through all the sheets in your workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]

    # --- BEATIFICATION STEP A: Auto-fit Column Widths ---
    for col in ws.columns:
        max_length = 0
        column = col[0].column_letter # Gets the letter (A, B, C...)
        
        # Find the longest string of text in the entire column
        for cell in col:
            try:
                if len(str(cell.value)) > max_length:
                    max_length = len(str(cell.value))
            except:
                pass
        
        # Add a little padding (+2) and set the new width. 
        # (We cap it at 75 so extremely long inclusion texts don't stretch the screen too far)
        adjusted_width = min(max_length + 2, 75) 
        ws.column_dimensions[column].width = adjusted_width

    # --- BEATIFICATION STEP B: Style the Header Row ---
    # Create a light gray fill and a bold font
    header_fill = PatternFill(start_color="E0E0E0", end_color="E0E0E0", fill_type="solid")
    header_font = Font(bold=True, color="000000")

    # Apply the styling to every cell in the first row
    for cell in ws[1]: 
        cell.font = header_font
        cell.fill = header_fill
        # Center the text and wrap it if it gets too long
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)

# 3. Save the changes back to the file
wb.save(file_path)
print("Excel file successfully beautified!")
# Out:
# Applying formatting to ../result/icd9_inclusion_mapping_summary_PubMedBERT.xlsx...
# Excel file successfully beautified!
